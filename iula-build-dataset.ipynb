# %%
import os
import glob
import pandas as pd

# %% [markdown]
# ### Procesar Corpus

# %%
keys = {
    'a':'ambiente',
    'm':'medicina',
    'i':'technologia',
    'e':'economia',
    'd':'legal',
}

def sentences(corpusroot: str, split: float=.2) -> pd.DataFrame:
    listfiles = glob.glob(corpusroot + '/*/*-plain.txt')
    corpus = []
    for fname in listfiles:
        cl = os.path.basename(fname)[0]
        with open(fname) as f:
            lines = f.readlines()
            for l in lines:
                l = l.strip()
                if len(l) > 1:
                    corpus.append( {'label':keys[cl], 'sentence':l } )
    co = pd.DataFrame(corpus)
    co['is_valid'] = (co.index % (1./split) == 0)
    return co

# %%
co_df = sentences('/content/drive/MyDrive/IULAcorpus/ES', split=.20)
co_df.to_csv('/content/drive/MyDrive/iula-es.csv')

# %%
num_labels = co_df['label'].nunique()
co_df
# Out:
#           label                                           sentence  is_valid
# 0      economia              LOS POSTULADOS DE LA ECONOMÍA CLÁSICA      True
# 1      economia  La mayor parte de los tratados sobre la teoría...     False
# 2      economia  También se ha sujetado con frecuencia a un pro...     False
# 3      economia  Decir que no se ha considerado en absoluto, se...     False
# 4      economia  No quiero decir que se haya pasado por alto, s...     False
# ...         ...                                                ...       ...
# 52350  medicina                                           Diarrea.      True
# 52351  medicina                                         Debilidad.     False
# 52352  medicina                                    Gusto alterado.     False
# 52353  medicina                           Parestesias peribucales.     False
# 52354  medicina                               Total de abandonos .     False
#
# [52355 rows x 3 columns]
